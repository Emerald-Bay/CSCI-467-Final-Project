# %% [markdown]
# # 🚀 CS:GO Initial ML (PyCaret)
# This notebook aims at using PyCaret to model CS:GO players dataset.
# First we use ``compare_model()`` method to evaluate a set of available methods.
# Afterwards, we will use the best model to create a ML model and tune it.
# Finally we report the results in the form of confusion matrix and basic metrics.

# %%
# Required Modluels
import os
import json
import pandas as pd
import pycaret

from collections import defaultdict

import pycaret
from pycaret.regression import *

# from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score


import sys
import platform
from datetime import date
print(f"  System: {sys.platform}")
print(f"  Python version: {platform.python_version()}")
print(f"  Last update: {date.today().strftime('%Y-%m-%d')}")
# Out:
#   System: darwin
#   Python version: 3.11.8
#   Last update: 2024-03-26

# %% [markdown]
# # 📊 Dataset
# **Note:** The dataset used in this notebook is subject to change.

# %%
# Load dataset

# Paths to save
folder_model_path = f"models"
folder_eval_path = f"evaluation/metrics/"
folder_report_path = f"evaluation/reports"

folder_prediction_path = f"predictions"

# Path to load datasets
folder_data_ml_path = f"data/"
folder_processed_path = f"data/processed"


df = pd.read_csv(f"{folder_data_ml_path}/csgo_players.csv", low_memory=False)

df.head()
# Out:
#    player_id nickname            real_name  age  country   current_team  \
# 0      11893    ZywOo      Mathieu Herbaut   21   France       Vitality
# 1       7998   s1mple  Aleksandr Kostyliev   24  Ukraine  Natus Vincere
# 2      16920    sh1ro       Dmitry Sokolov   21   Russia         Cloud9
# 3      20113     deko         Denis Zhukov   21   Russia           1WIN
# 4      18835   saffee         Rafael Costa   27   Brazil          FURIA
#
#                        teams  total_kills  total_deaths headshot_percentage  \
# 0              Vitality, aAa        22622         16458               41.2%
# 1              Natus Vincere        35512         26413               41.3%
# 2  Gambit Youngsters, Gambit        18091         12492               27.8%
# 3                       1WIN         8738          6397               36.7%
# 4                FURIA, paiN         8482          6517               30.9%
#
#    ...  3_kill_rounds  4_kill_rounds  5_kill_rounds  rifle_kills  \
# 0  ...           1474            369             71         8261
# 1  ...           2262            504             64        14717
# 2  ...           1075            221             30         3791
# 3  ...            518            112              8         2664
# 4  ...            524            114             14         2545
#
#    sniper_kills  smg_kills  pistol_kills  grenade_kills  other_kills  rating
# 0          8552       1290          4262            260           49    1.32
# 1         13451        901          6057            199          254    1.25
# 2         10580        550          3008            175           70    1.26
# 3          4348        181          1459             86           40    1.23
# 4          4412        264          1209             52           28    1.22
#
# [5 rows x 41 columns]

# %%
df.columns
# Out:
# Index(['player_id', 'nickname', 'real_name', 'age', 'country', 'current_team',
#        'teams', 'total_kills', 'total_deaths', 'headshot_percentage',
#        'damage_per_round', 'grenade_dmg_per_round', 'maps_played',
#        'rounds_played', 'kills_per_death', 'kills_per_round',
#        'assists_per_round', 'deaths_per_round', 'saved_by_teammate_per_round',
#        'saved_teammates_per_round', 'rounds_with_kills', 'kill_to_death_diff',
#        'total_opening_kills', 'total_opening_deaths', 'opening_kill_ratio',
#        'opening_kill_rating', 'team_win_percent_after_first_kill',
#        'first_kill_in_won_rounds', '0_kill_rounds', '1_kill_rounds',
#        '2_kill_rounds', '3_kill_rounds', '4_kill_rounds', '5_kill_rounds',
#        'rifle_kills', 'sniper_kills', 'smg_kills', 'pistol_kills',
#        'grenade_kills', 'other_kills', 'rating'],
#       dtype='object')

# %% [markdown]
# # 🤓 Preprocess Data
# In this section, we will preprocess the dataset and get it ready for Machine Learning

# %%
#remove unneeded col's (stats)
cols_Remove = [0, 1, 2, 5, 6, 7, 8, 21, 22, 23, 25]
df = df.drop(df.columns[cols_Remove], axis=1)

#divide specific stats by rounds for normalization
cols_label_Divide = ["0_kill_rounds", "1_kill_rounds", "2_kill_rounds", "3_kill_rounds", "4_kill_rounds", "5_kill_rounds", "rifle_kills", "sniper_kills", "smg_kills", "pistol_kills", "grenade_kills", "other_kills"]

#Iterate over the columns and perform division
for col in cols_label_Divide:
    df[col] = df[col] / df["rounds_played"]
   
print(df.iloc[0])
# Out:
# age                                        21
# country                                France
# headshot_percentage                     41.2%
# damage_per_round                         88.0
# grenade_dmg_per_round                     3.6
# maps_played                              1020
# rounds_played                           26803
# kills_per_death                          1.37
# kills_per_round                          0.84
# assists_per_round                        0.12
# deaths_per_round                         0.61
# saved_by_teammate_per_round               0.1
# saved_teammates_per_round                0.12
# rounds_with_kills                       14196
# opening_kill_ratio                        1.6
# team_win_percent_after_first_kill       73.1%
# first_kill_in_won_rounds                21.4%
# 0_kill_rounds                        0.470358
# 1_kill_rounds                        0.305749
# 2_kill_rounds                        0.152483
# 3_kill_rounds                        0.054994
# 4_kill_rounds                        0.013767
# 5_kill_rounds                        0.002649
# rifle_kills                          0.308212
# sniper_kills                         0.319069
# smg_kills                            0.048129
# pistol_kills                         0.159012
# grenade_kills                          0.0097
# other_kills                          0.001828
# rating                                   1.32
# Name: 0, dtype: object

# %% [markdown]
# # 🌎 General ML models
# In this section, we create an experiment to evaluate different models. To this end, we require to perform the following steps:
# 1. Create an experiment object
# 2. Create a setup dictionary and setup the environment
# 3. perfomt the model comparison
# 4. evaluate model to observe the initial performance

# %%
# Define PyCaret classificaiton experimetn
obj_exp = RegressionExperiment()

# %%
# Configure and build the setup environment
steup_dict= {
                "data": df,
                "fold": 10,
                "target": "rating",
                "index": True,
                "session_id": 420,
                "experiment_name": "experiment_csgo_initial",
                "normalize": True,
                "normalize_method": "zscore",
                "verbose": True
            }

obj_exp.setup(**steup_dict)
# Out:
# <style type="text/css">
# #T_89f7a_row9_col1, #T_89f7a_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_89f7a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89f7a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_89f7a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89f7a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89f7a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_89f7a_row0_col1" class="data row0 col1" >420</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89f7a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_89f7a_row1_col1" class="data row1 col1" >rating</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_89f7a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_89f7a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89f7a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_89f7a_row3_col1" class="data row3 col1" >(811, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_89f7a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_89f7a_row4_col1" class="data row4 col1" >(811, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_89f7a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_89f7a_row5_col1" class="data row5 col1" >(567, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_89f7a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_89f7a_row6_col1" class="data row6 col1" >(244, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_89f7a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_89f7a_row7_col1" class="data row7 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_89f7a_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_89f7a_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_89f7a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_89f7a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_89f7a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_89f7a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_89f7a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_89f7a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_89f7a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_89f7a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_89f7a_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_89f7a_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_89f7a_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_89f7a_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_89f7a_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_89f7a_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_89f7a_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_89f7a_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_89f7a_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_89f7a_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_89f7a_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_89f7a_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_89f7a_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_89f7a_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_89f7a_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_89f7a_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_89f7a_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_89f7a_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_89f7a_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_89f7a_row22_col1" class="data row22 col1" >experiment_csgo_initial</td>
#     </tr>
#     <tr>
#       <th id="T_89f7a_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_89f7a_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_89f7a_row23_col1" class="data row23 col1" >20b8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Perform the model comparison
best = obj_exp.compare_models()
# Out:
# <style type="text/css">
# #T_bc44a th {
#   text-align: left;
# }
# #T_bc44a_row0_col0, #T_bc44a_row1_col0, #T_bc44a_row1_col3, #T_bc44a_row1_col4, #T_bc44a_row2_col0, #T_bc44a_row2_col1, #T_bc44a_row2_col3, #T_bc44a_row2_col4, #T_bc44a_row2_col5, #T_bc44a_row2_col6, #T_bc44a_row3_col0, #T_bc44a_row3_col1, #T_bc44a_row3_col3, #T_bc44a_row3_col4, #T_bc44a_row3_col5, #T_bc44a_row3_col6, #T_bc44a_row4_col0, #T_bc44a_row4_col1, #T_bc44a_row4_col3, #T_bc44a_row4_col4, #T_bc44a_row4_col5, #T_bc44a_row4_col6, #T_bc44a_row5_col0, #T_bc44a_row5_col1, #T_bc44a_row5_col2, #T_bc44a_row5_col3, #T_bc44a_row5_col4, #T_bc44a_row5_col5, #T_bc44a_row5_col6, #T_bc44a_row6_col0, #T_bc44a_row6_col1, #T_bc44a_row6_col2, #T_bc44a_row6_col3, #T_bc44a_row6_col4, #T_bc44a_row6_col5, #T_bc44a_row6_col6, #T_bc44a_row7_col0, #T_bc44a_row7_col1, #T_bc44a_row7_col2, #T_bc44a_row7_col3, #T_bc44a_row7_col4, #T_bc44a_row7_col5, #T_bc44a_row7_col6, #T_bc44a_row8_col0, #T_bc44a_row8_col1, #T_bc44a_row8_col2, #T_bc44a_row8_col3, #T_bc44a_row8_col4, #T_bc44a_row8_col5, #T_bc44a_row8_col6, #T_bc44a_row9_col0, #T_bc44a_row9_col1, #T_bc44a_row9_col2, #T_bc44a_row9_col3, #T_bc44a_row9_col4, #T_bc44a_row9_col5, #T_bc44a_row9_col6, #T_bc44a_row10_col0, #T_bc44a_row10_col1, #T_bc44a_row10_col2, #T_bc44a_row10_col3, #T_bc44a_row10_col4, #T_bc44a_row10_col5, #T_bc44a_row10_col6, #T_bc44a_row11_col0, #T_bc44a_row11_col1, #T_bc44a_row11_col2, #T_bc44a_row11_col3, #T_bc44a_row11_col4, #T_bc44a_row11_col5, #T_bc44a_row11_col6, #T_bc44a_row12_col0, #T_bc44a_row12_col1, #T_bc44a_row12_col2, #T_bc44a_row12_col3, #T_bc44a_row12_col4, #T_bc44a_row12_col5, #T_bc44a_row12_col6, #T_bc44a_row13_col0, #T_bc44a_row13_col1, #T_bc44a_row13_col2, #T_bc44a_row13_col3, #T_bc44a_row13_col4, #T_bc44a_row13_col5, #T_bc44a_row13_col6, #T_bc44a_row14_col0, #T_bc44a_row14_col1, #T_bc44a_row14_col2, #T_bc44a_row14_col3, #T_bc44a_row14_col4, #T_bc44a_row14_col5, #T_bc44a_row14_col6, #T_bc44a_row15_col0, #T_bc44a_row15_col1, #T_bc44a_row15_col2, #T_bc44a_row15_col3, #T_bc44a_row15_col4, #T_bc44a_row15_col5, #T_bc44a_row15_col6, #T_bc44a_row16_col0, #T_bc44a_row16_col1, #T_bc44a_row16_col2, #T_bc44a_row16_col3, #T_bc44a_row16_col4, #T_bc44a_row16_col5, #T_bc44a_row16_col6, #T_bc44a_row17_col0, #T_bc44a_row17_col1, #T_bc44a_row17_col2, #T_bc44a_row17_col3, #T_bc44a_row17_col4, #T_bc44a_row17_col5, #T_bc44a_row17_col6 {
#   text-align: left;
# }
# #T_bc44a_row0_col1, #T_bc44a_row0_col2, #T_bc44a_row0_col3, #T_bc44a_row0_col4, #T_bc44a_row0_col5, #T_bc44a_row0_col6, #T_bc44a_row1_col1, #T_bc44a_row1_col2, #T_bc44a_row1_col5, #T_bc44a_row1_col6, #T_bc44a_row2_col2, #T_bc44a_row3_col2, #T_bc44a_row4_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bc44a_row0_col7, #T_bc44a_row1_col7, #T_bc44a_row2_col7, #T_bc44a_row3_col7, #T_bc44a_row4_col7, #T_bc44a_row5_col7, #T_bc44a_row6_col7, #T_bc44a_row7_col7, #T_bc44a_row8_col7, #T_bc44a_row9_col7, #T_bc44a_row10_col7, #T_bc44a_row11_col7, #T_bc44a_row13_col7, #T_bc44a_row14_col7, #T_bc44a_row15_col7, #T_bc44a_row16_col7, #T_bc44a_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_bc44a_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bc44a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc44a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bc44a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bc44a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bc44a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bc44a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bc44a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bc44a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bc44a_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc44a_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_bc44a_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_bc44a_row0_col1" class="data row0 col1" >0.0192</td>
#       <td id="T_bc44a_row0_col2" class="data row0 col2" >0.0006</td>
#       <td id="T_bc44a_row0_col3" class="data row0 col3" >0.0234</td>
#       <td id="T_bc44a_row0_col4" class="data row0 col4" >0.8974</td>
#       <td id="T_bc44a_row0_col5" class="data row0 col5" >0.0116</td>
#       <td id="T_bc44a_row0_col6" class="data row0 col6" >0.0187</td>
#       <td id="T_bc44a_row0_col7" class="data row0 col7" >0.2600</td>
#     </tr>
#     <tr>
#       <th id="T_bc44a_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_bc44a_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_bc44a_row1_col1" class="data row1 col1" >0.0192</td>
#       <td id="T_bc44a_row1_col2" class="data row1 col2" >0.0006</td>
#       <td id="T_bc44a_row1_col3" class="data row1 col3" >0.0235</td>
#       <td id="T_bc44a_row1_col4" class="data row1 col4" >0.8966</td>
#       <td id="T_bc44a_row1_col5" class="data row1 col5" >0.0116</td>
#       <td id="T_bc44a_row1_col6" class="data row1 col6" >0.0187</td>
#       <td id="T_bc44a_row1_col7" class="data row1 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_bc44a_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_bc44a_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_bc44a_row2_col1" class="data row2 col1" >0.0193</td>
#       <td id="T_bc44a_row2_col2" class="data row2 col2" >0.0006</td>
#       <td id="T_bc44a_row2_col3" class="data row2 col3" >0.0236</td>
#       <td id="T_bc44a_row2_col4" class="data row2 col4" >0.8958</td>
#       <td id="T_bc44a_row2_col5" class="data row2 col5" >0.0117</td>
#       <td id="T_bc44a_row2_col6" class="data row2 col6" >0.0188</td>
#       <td id="T_bc44a_row2_col7" class="data row2 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_bc44a_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_bc44a_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_bc44a_row3_col1" class="data row3 col1" >0.0195</td>
#       <td id="T_bc44a_row3_col2" class="data row3 col2" >0.0006</td>
#       <td id="T_bc44a_row3_col3" class="data row3 col3" >0.0239</td>
#       <td id="T_bc44a_row3_col4" class="data row3 col4" >0.8929</td>
#       <td id="T_bc44a_row3_col5" class="data row3 col5" >0.0118</td>
#       <td id="T_bc44a_row3_col6" class="data row3 col6" >0.0190</td>
#       <td id="T_bc44a_row3_col7" class="data row3 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_bc44a_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_bc44a_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_bc44a_row4_col1" class="data row4 col1" >0.0198</td>
#       <td id="T_bc44a_row4_col2" class="data row4 col2" >0.0006</td>
#       <td id="T_bc44a_row4_col3" class="data row4 col3" >0.0253</td>
#       <td id="T_bc44a_row4_col4" class="data row4 col4" >0.8803</td>
#       <td id="T_bc44a_row4_col5" class="data row4 col5" >0.0125</td>
#       <td id="T_bc44a_row4_col6" class="data row4 col6" >0.0193</td>
#       <td id="T_bc44a_row4_col7" class="data row4 col7" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_bc44a_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_bc44a_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_bc44a_row5_col1" class="data row5 col1" >0.0213</td>
#       <td id="T_bc44a_row5_col2" class="data row5 col2" >0.0007</td>
#       <td id="T_bc44a_row5_col3" class="data row5 col3" >0.0258</td>
#       <td id="T_bc44a_row5_col4" class="data row5 col4" >0.8762</td>
#       <td id="T_bc44a_row5_col5" class="data row5 col5" >0.0127</td>
#       <td id="T_bc44a_row5_col6" class="data row5 col6" >0.0207</td>
#       <td id="T_bc44a_row5_col7" class="data row5 col7" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_bc44a_level0_row6" class="row_heading level0 row

# %%
obj_exp.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # ✅ Best ML Model
# In this section we use the ML model obtained from the previous step to:
# 1. Create the model
# 2. Tune the model
# 3. Finalize the model
# 4. Evaluate the model performance (metrics)
