# %% [markdown]
# # 🚀 CS:GO Initial ML (PyCaret)
# This notebook aims at using PyCaret to model CS:GO players dataset.
# First we use ``compare_model()`` method to evaluate a set of available methods.
# Afterwards, we will use the best model to create a ML model and tune it.
# Finally we report the results in the form of confusion matrix and basic metrics.

# %%
# Required Modluels
import os
import json
import pandas as pd
import pycaret

from collections import defaultdict

import pycaret
from pycaret.classification import *

# from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score


import sys
import platform
from datetime import date
print(f"  System: {sys.platform}")
print(f"  Python version: {platform.python_version()}")
print(f"  Last update: {date.today().strftime('%Y-%m-%d')}")
# Out:
#   System: darwin
#   Python version: 3.11.8
#   Last update: 2024-03-26

# %% [markdown]
# # 📊 Dataset
# **Note:** The dataset used in this notebook is subject to change.

# %%
# Load dataset

# Paths to save
folder_model_path = f"models"
folder_eval_path = f"evaluation/metrics/"
folder_report_path = f"evaluation/reports"

folder_prediction_path = f"predictions"

# Path to load datasets
folder_data_ml_path = f"data/"
folder_processed_path = f"data/processed"


players_df = pd.read_csv('data/players.csv')
results_df = pd.read_csv('data/results.csv')

df = pd.read_csv('updated_players.csv')
df.head()
# Out:
#          date player_name           team       opponent        country  \
# 0  2020-02-26      Brehze  Evil Geniuses         Liquid  United States
# 1  2020-02-26        CeRq  Evil Geniuses         Liquid       Bulgaria
# 2  2020-02-26       EliGE         Liquid  Evil Geniuses  United States
# 3  2020-02-26       Ethan  Evil Geniuses         Liquid  United States
# 4  2020-02-26         NAF         Liquid  Evil Geniuses         Canada
#
#    player_id  match_id  event_id         event_name  best_of  ... m3_adr_ct  \
# 0       9136   2339385      4901  IEM Katowice 2020        3  ...      72.5
# 1      11219   2339385      4901  IEM Katowice 2020        3  ...      79.5
# 2       8738   2339385      4901  IEM Katowice 2020        3  ...      81.5
# 3      10671   2339385      4901  IEM Katowice 2020        3  ...      67.2
# 4       8520   2339385      4901  IEM Katowice 2020        3  ...      72.9
#
#   m3_kast_ct m3_rating_ct  m3_kills_t  m3_deaths_t  m3_kddiff_t  m3_adr_t  \
# 0       80.0         0.93         7.0          9.0         -2.0      70.4
# 1       53.3         1.12         4.0          8.0         -4.0      40.7
# 2       63.6         1.03         9.0          9.0          0.0      87.9
# 3       66.7         0.97         1.0          9.0         -8.0      14.8
# 4       81.8         0.96         8.0          7.0          1.0      56.3
#
#    m3_kast_t  m3_rating_t  team_won
# 0       63.6         0.89       0.0
# 1       54.5         0.53       0.0
# 2       73.3         1.05       1.0
# 3       45.5         0.31       0.0
# 4       80.0         0.99       1.0
#
# [5 rows x 102 columns]

# %%
df.columns
# Out:
# Index(['date', 'player_name', 'team', 'opponent', 'country', 'player_id',
#        'match_id', 'event_id', 'event_name', 'best_of',
#        ...
#        'm3_adr_ct', 'm3_kast_ct', 'm3_rating_ct', 'm3_kills_t', 'm3_deaths_t',
#        'm3_kddiff_t', 'm3_adr_t', 'm3_kast_t', 'm3_rating_t', 'team_won'],
#       dtype='object', length=102)

# %% [markdown]
# # 🤓 Preprocess Data
# In this section, we will preprocess the dataset and get it ready for Machine Learning

# %%
# #remove unneeded col's (stats)
# cols_Remove = [0, 1, 2, 5, 6, 7, 8, 21, 22, 23, 25]
# df = df.drop(df.columns[cols_Remove], axis=1)

# #divide specific stats by rounds for normalization
# cols_label_Divide = ["0_kill_rounds", "1_kill_rounds", "2_kill_rounds", "3_kill_rounds", "4_kill_rounds", "5_kill_rounds", "rifle_kills", "sniper_kills", "smg_kills", "pistol_kills", "grenade_kills", "other_kills"]

# #Iterate over the columns and perform division
# for col in cols_label_Divide:
#     df[col] = df[col] / df["rounds_played"]
   
# print(df.iloc[0])

# %%
df.shape
# Out:
# (383317, 102)

# %%
df.dropna(subset=['team_won'], inplace=True)


df = df[df['best_of'] == 3]
df.shape
# Out:
# (119630, 102)

# %%
columns_to_keep = [
    'date', 'player_name', 'team', 'opponent', 'country',
    'player_id', 'match_id', 'event_id', 'event_name',
    'best_of', 'map_1','map_2','map_3','team_won', 
    'm1_kills', 'm1_assists', 'm1_deaths', 'm1_hs', 'm1_flash_assists',
    'm1_kast', 'm1_kddiff', 'm1_adr', 'm1_fkdiff', 'm1_rating'
]


df = df[columns_to_keep]
df.shape
# Out:
# (119630, 24)

# %% [markdown]
# # 🌎 General ML models
# In this section, we create an experiment to evaluate different models. To this end, we require to perform the following steps:
# 1. Create an experiment object
# 2. Create a setup dictionary and setup the environment
# 3. perfomt the model comparison
# 4. evaluate model to observe the initial performance

# %%
# Define PyCaret classificaiton experimetn
obj_exp = ClassificationExperiment()

# %%
# Configure and build the setup environment
steup_dict= {
                "data": df,
                "fold": 10,
                "target": "team_won",
                "index": True,
                "ignore_features": [
                        'date', 'player_name', 
                    # 'team', 'opponent', 
                    'country',
                        'player_id', 'match_id', 'event_id', 'event_name',
                        'best_of',
                    ],
                "session_id": 420,
                "experiment_name": "experiment_csgo_initial",
                "normalize": True,
                "normalize_method": "zscore",
                "verbose": True
            }

obj_exp.setup(**steup_dict)
# Out:
# <style type="text/css">
# #T_94017_row11_col1, #T_94017_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_94017">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94017_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_94017_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94017_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94017_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_94017_row0_col1" class="data row0 col1" >420</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94017_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_94017_row1_col1" class="data row1 col1" >team_won</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94017_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_94017_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94017_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_94017_row3_col1" class="data row3 col1" >(119630, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94017_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_94017_row4_col1" class="data row4 col1" >(119630, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94017_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_94017_row5_col1" class="data row5 col1" >(83741, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94017_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_94017_row6_col1" class="data row6 col1" >(35889, 41)</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94017_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_94017_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94017_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_94017_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94017_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_94017_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_94017_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_94017_row10_col1" class="data row10 col1" >71.0%</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_94017_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_94017_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_94017_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_94017_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_94017_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_94017_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_94017_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_94017_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_94017_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_94017_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_94017_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_94017_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_94017_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_94017_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_94017_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_94017_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_94017_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_94017_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_94017_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_94017_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_94017_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_94017_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_94017_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_94017_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_94017_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_94017_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_94017_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_94017_row24_col1" class="data row24 col1" >experiment_csgo_initial</td>
#     </tr>
#     <tr>
#       <th id="T_94017_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_94017_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_94017_row25_col1" class="data row25 col1" >3899</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Perform the model comparison
best = obj_exp.compare_models()
# Out:
# <style type="text/css">
# #T_0177a th {
#   text-align: left;
# }
# #T_0177a_row0_col0, #T_0177a_row0_col3, #T_0177a_row1_col0, #T_0177a_row1_col1, #T_0177a_row1_col3, #T_0177a_row1_col4, #T_0177a_row1_col5, #T_0177a_row1_col6, #T_0177a_row1_col7, #T_0177a_row2_col0, #T_0177a_row2_col1, #T_0177a_row2_col3, #T_0177a_row2_col4, #T_0177a_row2_col5, #T_0177a_row2_col6, #T_0177a_row2_col7, #T_0177a_row3_col0, #T_0177a_row3_col1, #T_0177a_row3_col3, #T_0177a_row3_col4, #T_0177a_row3_col5, #T_0177a_row3_col6, #T_0177a_row3_col7, #T_0177a_row4_col0, #T_0177a_row4_col1, #T_0177a_row4_col3, #T_0177a_row4_col4, #T_0177a_row4_col5, #T_0177a_row4_col6, #T_0177a_row4_col7, #T_0177a_row5_col0, #T_0177a_row5_col1, #T_0177a_row5_col3, #T_0177a_row5_col4, #T_0177a_row5_col5, #T_0177a_row5_col6, #T_0177a_row5_col7, #T_0177a_row6_col0, #T_0177a_row6_col1, #T_0177a_row6_col3, #T_0177a_row6_col4, #T_0177a_row6_col5, #T_0177a_row6_col6, #T_0177a_row6_col7, #T_0177a_row7_col0, #T_0177a_row7_col1, #T_0177a_row7_col3, #T_0177a_row7_col4, #T_0177a_row7_col5, #T_0177a_row7_col6, #T_0177a_row7_col7, #T_0177a_row8_col0, #T_0177a_row8_col1, #T_0177a_row8_col3, #T_0177a_row8_col4, #T_0177a_row8_col5, #T_0177a_row8_col6, #T_0177a_row8_col7, #T_0177a_row9_col0, #T_0177a_row9_col1, #T_0177a_row9_col3, #T_0177a_row9_col4, #T_0177a_row9_col5, #T_0177a_row9_col6, #T_0177a_row9_col7, #T_0177a_row10_col0, #T_0177a_row10_col1, #T_0177a_row10_col3, #T_0177a_row10_col4, #T_0177a_row10_col5, #T_0177a_row10_col6, #T_0177a_row10_col7, #T_0177a_row11_col0, #T_0177a_row11_col1, #T_0177a_row11_col3, #T_0177a_row11_col4, #T_0177a_row11_col5, #T_0177a_row11_col6, #T_0177a_row11_col7, #T_0177a_row12_col0, #T_0177a_row12_col1, #T_0177a_row12_col3, #T_0177a_row12_col4, #T_0177a_row12_col5, #T_0177a_row12_col6, #T_0177a_row12_col7, #T_0177a_row13_col0, #T_0177a_row13_col1, #T_0177a_row13_col4, #T_0177a_row13_col5, #T_0177a_row13_col6, #T_0177a_row13_col7 {
#   text-align: left;
# }
# #T_0177a_row0_col1, #T_0177a_row0_col2, #T_0177a_row0_col4, #T_0177a_row0_col5, #T_0177a_row0_col6, #T_0177a_row0_col7, #T_0177a_row1_col2, #T_0177a_row2_col2, #T_0177a_row3_col2, #T_0177a_row4_col2, #T_0177a_row5_col2, #T_0177a_row6_col2, #T_0177a_row7_col2, #T_0177a_row8_col2, #T_0177a_row9_col2, #T_0177a_row10_col2, #T_0177a_row11_col2, #T_0177a_row12_col2, #T_0177a_row13_col2, #T_0177a_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0177a_row0_col8, #T_0177a_row1_col8, #T_0177a_row2_col8, #T_0177a_row3_col8, #T_0177a_row4_col8, #T_0177a_row5_col8, #T_0177a_row6_col8, #T_0177a_row7_col8, #T_0177a_row8_col8, #T_0177a_row9_col8, #T_0177a_row10_col8, #T_0177a_row12_col8, #T_0177a_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0177a_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0177a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0177a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0177a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0177a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0177a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0177a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0177a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0177a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0177a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0177a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0177a_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_0177a_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_0177a_row0_col1" class="data row0 col1" >0.7909</td>
#       <td id="T_0177a_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_0177a_row0_col3" class="data row0 col3" >0.7777</td>
#       <td id="T_0177a_row0_col4" class="data row0 col4" >0.7988</td>
#       <td id="T_0177a_row0_col5" class="data row0 col5" >0.7881</td>
#       <td id="T_0177a_row0_col6" class="data row0 col6" >0.5818</td>
#       <td id="T_0177a_row0_col7" class="data row0 col7" >0.5820</td>
#       <td id="T_0177a_row0_col8" class="data row0 col8" >1.9990</td>
#     </tr>
#     <tr>
#       <th id="T_0177a_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_0177a_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_0177a_row1_col1" class="data row1 col1" >0.7652</td>
#       <td id="T_0177a_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_0177a_row1_col3" class="data row1 col3" >0.7504</td>
#       <td id="T_0177a_row1_col4" class="data row1 col4" >0.7733</td>
#       <td id="T_0177a_row1_col5" class="data row1 col5" >0.7617</td>
#       <td id="T_0177a_row1_col6" class="data row1 col6" >0.5304</td>
#       <td id="T_0177a_row1_col7" class="data row1 col7" >0.5306</td>
#       <td id="T_0177a_row1_col8" class="data row1 col8" >2.0420</td>
#     </tr>
#     <tr>
#       <th id="T_0177a_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_0177a_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0177a_row2_col1" class="data row2 col1" >0.7606</td>
#       <td id="T_0177a_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_0177a_row2_col3" class="data row2 col3" >0.7553</td>
#       <td id="T_0177a_row2_col4" class="data row2 col4" >0.7635</td>
#       <td id="T_0177a_row2_col5" class="data row2 col5" >0.7594</td>
#       <td id="T_0177a_row2_col6" class="data row2 col6" >0.5212</td>
#       <td id="T_0177a_row2_col7" class="data row2 col7" >0.5213</td>
#       <td id="T_0177a_row2_col8" class="data row2 col8" >0.6790</td>
#     </tr>
#     <tr>
#       <th id="T_0177a_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_0177a_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0177a_row3_col1" class="data row3 col1" >0.7524</td>
#       <td id="T_0177a_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_0177a_row3_col3" class="data row3 col3" >0.7427</td>
#       <td id="T_0177a_row3_col4" class="data row3 col4" >0.7575</td>
#       <td id="T_0177a_row3_col5" class="data row3 col5" >0.7500</td>
#       <td id="T_0177a_row3_col6" class="data row3 col6" >0.5049</td>
#       <td id="T_0177a_row3_col7" class="data row3 col7" >0.5050</td>
#       <td id="T_0177a_row3_col8" class="data row3 col8" >2.6390</td>
#     </tr>
#     <tr>
#       <th id="T_0177a_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_0177a_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_0177a_row4_col1" class="data row4 col1" >0.7341</td>
#       <td id="T_0177a_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_0177a_row4_col3" class="data row4 col3" >0.7243</td>
#       <td id="T_0177a_row4_col4" class="data row4 col4" >0.7389</td>
#       <td id="T_0177a_row4_col5" class="data row4 col5" >0.7315</td>
#       <td id="T_0177a_row4_col6" class="data row4 col6" >0.4682</td>
#       <td id="T_0177a_row4_col7" class="data row4 col7" >0.4683</td>
#       <td id="T_0177a_row4_col8" class="data row4 col8" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_0177a_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_0177a_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0177a_row5_col1" class="data row5 col1" >0.7341</td>
#       <td id="T_0177a_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_0177a_row5_col3" class="data row5 col3" >0.7243</td>
#       <td id="T_0177a_row5_col4" class="data row5 col4" >0.7389</td>
#       <td id="T_0177a_row5_col5" class="data row5 col5" >0.7315</td>
#       <td id="T_0177a_row5_col6" class="data row5 col6" >0.4682</td>
#       <td id="T_0177a_row5_col7" class="data row5 col7" >0.4683</td

# %%
obj_exp.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # ✅ Best ML Model
# In this section we use the ML model obtained from the previous step to:
# 1. Create the model
# 2. Tune the model
# 3. Finalize the model
# 4. Evaluate the model performance (metrics)
